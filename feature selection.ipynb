# %% [markdown]
# # data analys cat variable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.model_selection import train_test_split
import statsmodels as st
from statsmodels.stats import outliers_influence
from statsmodels.api import Logit
import random
from sklearn.utils import shuffle
import math

# %%
data=pd.read_csv(r"C:\Users\HP 250\Desktop\preojec_banca\data_drop_unknown.csv")

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %%
data.drop(["default","housing","loan"],inplace=True,axis=1)

# %%
data
# Out:
#        Unnamed: 0  age           job   marital            education  \
# 0               1   37  entrepreneur   married    university.degree
# 1               2   78       retired   married             basic.4y
# 2               3   36        admin.   married    university.degree
# 3               4   59       retired  divorced    university.degree
# 4               5   29        admin.    single    university.degree
# ...           ...  ...           ...       ...                  ...
# 24300       32945   28      services    single          high.school
# 24301       32946   52    technician   married  professional.course
# 24302       32947   54        admin.   married             basic.9y
# 24303       32948   29        admin.   married    university.degree
# 24304       32949   35        admin.   married    university.degree
#
#          contact month day_of_week  duration  campaign  pdays  previous    y
# ...

# %% [markdown]
# # numerical variabloe

# %%
data1=data[data["y"]=="yes"]
data2=data[data["y"]=="no"]

# %%
plt.subplot(2,2,1)
sbn.boxplot(y=data1.duration)
plt.subplot(2,2,2)
sbn.boxplot(y=data2.duration)
# Out:
# <AxesSubplot: ylabel='duration'>

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ![download.png](attachment:download.png)#

# %%
data.to_csv(r"C:\Users\HP 250\Desktop\preojec_banca\feature_selected.csv")
